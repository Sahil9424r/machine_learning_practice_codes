# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR,SVC
from sklearn.preprocessing import LabelEncoder,StandardScaler,MaxAbsScaler,MinMaxScaler,OneHotEncoder
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns

# %%
df=pd.read_csv("Train.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.shape
# Out:
# (2000, 21)

# %%
# l=LabelEncoder()
l=MinMaxScaler()
df.px_width	=l.fit_transform(df[['px_width']])
df.ram=l.fit_transform(df[['ram']])
df.battery_power=l.fit_transform(df[['battery_power']])
df.mobile_wt=l.fit_transform(df[['mobile_wt']])
df.px_height =l.fit_transform(df[['px_height']] )
df.int_memory =l.fit_transform(df[['int_memory']] )

x=df.drop('price_range',axis=1)
y=df.price_range

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0       0.227789     0          2.2         0   1       0    0.080645    0.6
# 1       0.347361     1          0.5         1   0       1    0.822581    0.7
# 2       0.041416     1          0.5         1   2       1    0.629032    0.9
# 3       0.076152     1          2.5         0   0       0    0.129032    0.8
# 4       0.881764     1          1.2         0  13       1    0.677419    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width       ram  sc_h  sc_w  \
# 0   0.900000        2  ...   0.010204  0.170895  0.612774     9     7
# 1   0.466667        3  ...   0.461735  0.993324  0.634687    17     3
# 2   0.541667        5  ...   0.644388  0.811749  0.627205    11     2
# 3   0.425000        6  ...   0.620408  0.858478  0.671566    16     8
# 4   0.508333        2  ...   0.616327  0.475300  0.308658     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df.price_range.unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# C:\Users\sahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8025
